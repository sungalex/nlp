# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#CSS-Selector" data-toc-modified-id="CSS-Selector-1">CSS Selector</a></span></li><li><span><a href="#CSS-Selector로-포탈-검색결과에서-제목-추출하기" data-toc-modified-id="CSS-Selector로-포탈-검색결과에서-제목-추출하기-2">CSS Selector로 포탈 검색결과에서 제목 추출하기</a></span></li><li><span><a href="#Crawling" data-toc-modified-id="Crawling-3">Crawling</a></span></li><li><span><a href="#webscraping.com-사이트에서-Crawling-실습" data-toc-modified-id="webscraping.com-사이트에서-Crawling-실습-4">webscraping.com 사이트에서 Crawling 실습</a></span><ul class="toc-item"><li><span><a href="#getUrls()-함수-만들기" data-toc-modified-id="getUrls()-함수-만들기-4.1">getUrls() 함수 만들기</a></span></li></ul></li><li><span><a href="#google-검색결과로-부터-External-Site-Crawling" data-toc-modified-id="google-검색결과로-부터-External-Site-Crawling-5">google 검색결과로 부터 External Site Crawling</a></span><ul class="toc-item"><li><span><a href="#getUrls()-함수-재정의(1)" data-toc-modified-id="getUrls()-함수-재정의(1)-5.1">getUrls() 함수 재정의(1)</a></span></li><li><span><a href="#getUrls()-함수-재정의(2)" data-toc-modified-id="getUrls()-함수-재정의(2)-5.2">getUrls() 함수 재정의(2)</a></span></li><li><span><a href="#crawling-함수를-사용" data-toc-modified-id="crawling-함수를-사용-5.3">crawling 함수를 사용</a></span></li></ul></li></ul></div>

# %%
from functions.download import getDownload
from functions.search import getPortalSearchUrl
from functions.search import getPortalToDOM
from bs4 import BeautifulSoup
import time
import random

# %%
# doms = getPortalToDOM("파이썬 자습서")    # (doms[0] == google, doms[1] == naver, doms[2] == daum, doms[3] == nate)
google, naver, daum, nate = getPortalToDOM("파이썬 자습서")   # 4대 포탈에서 지정 문자열을 검색 후 DOM 반환

# %%
portalUrls = getPortalSearchUrl()

# %%
googleUrl = portalUrls[0]

# %% [markdown]
# ## CSS Selector

# %% [markdown]
# - Selector : Tag, ID(#아이디), Class(.class)   --> dom.select()
# - name, ^name, name$ 등 이름의 일부로 검색 가능
# - div p => find_all(div 찾고, 자손 중에 p 찾기)
# - div > p => find_all(recursivr=False), div 찾고, 바로 아래 자손 중에 p 찾기
# - div + p => find(div).find_next_sibling(p)

# %% [markdown]
# ## CSS Selector로 포탈 검색결과에서 제목 추출하기

# %%
# 구글
for tag in google.select(".r > a > h3"):
    print(tag.text, tag.find_parent()["href"])
# Out:
# 파이썬 자습서 — Python 3.7.2 documentation https://docs.python.org/ko/3/tutorial/index.html
# 프로그래머가 아닌 이들을 위한 파이썬 3 자습서 - 위키책 https://ko.wikibooks.org/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EA%B0%80_%EC%95%84%EB%8B%8C_%EC%9D%B4%EB%93%A4%EC%9D%84_%EC%9C%84%ED%95%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_3_%EC%9E%90%EC%8A%B5%EC%84%9C
# byte of python(한국어판 PDF) - SourceForge http://byteofpython-korean.sourceforge.net/byte_of_python.pdf
# 파이썬 강좌 및 유용한 사이트 모음 : 네이버 블로그 http://blog.naver.com/koromoon/220578871433
# Visual Studio 자습서 1단계의 Python 프로젝트 만들기 | Microsoft Docs https://docs.microsoft.com/ko-kr/visualstudio/python/tutorial-working-with-python-in-visual-studio-step-01-create-project
# Python | 자습서, API, SDK, 설명서 | AWS 개발자 센터 - Amazon.com https://aws.amazon.com/ko/developer/language/python/
# 5.2 파이썬(Python) 시작하기 – Computational Thinking http://www.kucomputationalthink.org/index.php/chapter-5/5-2-getting-started-with-python/
# 무료 파이썬 자습서, eBook 및 전자책 - Blue Breeze https://bluebreeze.co.kr/833

# %%
# 네이버
for tag in naver.select(".type01 dt"):
    print(tag.a.text, tag.a["href"])
# Out:
# 파이썬 자습서 https://blog.naver.com/jhhamm?Redirect=Log&logNo=221415897996
# [python][ebook] 귀도의 파이썬 자습서(2.5) (한글 EBook) https://blog.naver.com/dev4unet?Redirect=Log&logNo=120193065174
# 자료 - 파이썬 자습서 http://blog.daum.net/skcs4/2382
# [파이선] 파이썬 자습서 (한글화가 잘 되어 있네요) http://cafe.naver.com/cortexsh/1653
# 파이썬 ve C언어 http://cafe.naver.com/cafec/378766
# 과학 전공도서/자습서/교양서적 등 팝니다~ http://cafe.naver.com/joonggonara/545280936
# [nRF Mesh] Sending mesh packets [2-serial examples] http://cafe.naver.com/cortexsh/1694
# C언어를 배우기 전에 파이썬공부를 왜 하는가 http://cafe.naver.com/thdskarl/10317
# 파이썬, 주류 언어로 부상··· 티오베와 PyPL 지표에서 상위권 http://www.ciokorea.com/news/114426
# 떠오르는 심층 신경망 API, "케라스" 알아보기 http://www.itworld.co.kr/news/116583
# IT전문가를 위한 라즈베리 파이 프로젝트 13선 http://www.ciokorea.com/news/113478
# 개발자 출신 빅토리아시크릿 모델 ... '뇌섹녀' 인증 http://www.fnnews.com/news/201809111029096827
# 기술력 향상을 도울 온라인 무료 교육 사이트 8선 http://www.ciokorea.com/news/38589
# 올해 대학 합격하고 컴퓨터 공학과에 https://kin.naver.com/qna/detail.nhn?d1id=11&dirId=1113&docId=320102309&qb=7YyM7J207I2sIOyekOyKteyEnA==&enc=utf8&section=kin&rank=1&search_sort=0&spq=0
# 경북대학교 소프트웨어학과 진학에 관해서 https://kin.naver.com/qna/detail.nhn?d1id=1&dirId=10405&docId=297058448&qb=7YyM7J207I2sIOyekOyKteyEnA==&enc=utf8&section=kin&rank=2&search_sort=0&spq=0
# 고1 공부법 및 진로 https://kin.naver.com/qna/detail.nhn?d1id=11&dirId=1104&docId=297769561&qb=7YyM7J207I2sIOyekOyKteyEnA==&enc=utf8&section=kin&rank=3&search_sort=0&spq=0
# The Python Tutorial — Python 3.7.2 documentation https://docs.python.org/3/tutorial/index.html
# 프로그래머가 아닌 이들을 위한 파이썬 3 자습서 https://ko.wikibooks.org/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EA%B0%80_%EC%95%84%EB%8B%8C_%EC%9D%B4%EB%93%A4%EC%9D%84_%EC%9C%84%ED%95%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_3_%EC%9E%90%EC%8A%B5%EC%84%9C
# 프로그래머가 아닌 이들을 위한 파이썬 3 자습서/재귀 https://ko.wikibooks.org/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EA%B0%80_%EC%95%84%EB%8B%8C_%EC%9D%B4%EB%93%A4%EC%9D%84_%EC%9C%84%ED%95%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_3_%EC%9E%90%EC%8A%B5%EC%84%9C/%EC%9E%AC%EA%B7%80

# %%
# 다음
for tag in daum.select(".mg_tit > a"):
    print(tag.text.strip(), tag["href"])
# Out:
# [파이썬기초] 자습서 http://jinbonews.tistory.com/8
# 무료 파이썬 자습서, eBook 및 전자책 http://bluebreeze.co.kr/833
# [python][ebook] 귀도의 파이썬 자습서(2.5) (한글 EBook) http://blog.naver.com/PostView.nhn?blogId=dev4unet&logNo=120193065174
# python자습서_ 숫자, 문자열 http://make-it-developer.tistory.com/21
# 파이썬 자습서 ¶ https://docs.python.org/ko/3.7/tutorial/index.html
# 【免費教育APP】파이썬 자습서|線上玩APP不花錢 http://searchapp.soft4fun.net/article/information/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9E%90%EC%8A%B5%EC%84%9C/4122219
# 프로그래머가 아닌 이들을 위한 파이썬 3 자습서/서문 http://ko.m.wikibooks.nym.mx/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EA%B0%80_%EC%95%84%EB%8B%8C_%EC%9D%B4%EB%93%A4%EC%9D%84_%EC%9C%84%ED%95%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_3_%EC%9E%90%EC%8A%B5%EC%84%9C/%EC%84%9C%EB%AC%B8
# 프로그래머가 아닌 이들을 위한 파이썬 3 자습서/FAQ http://ko.m.wikibooks.nom.rs/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EA%B0%80_%EC%95%84%EB%8B%8C_%EC%9D%B4%EB%93%A4%EC%9D%84_%EC%9C%84%ED%95%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_3_%EC%9E%90%EC%8A%B5%EC%84%9C/FAQ
# 떠오르는 심층 신경망 API, "케라스" 알아보기 https://cp.news.search.daum.net/p/76899725
# 파이썬, 주류 언어로 부상··· 티오베와 PyPL 지표에서 상위권 https://cp.news.search.daum.net/p/76900731
# IT전문가를 위한 라즈베리 파이 프로젝트 13선 https://cp.news.search.daum.net/p/76901247
# 개발자 출신 빅토리아시크릿 모델 .. '뇌섹녀' 인증 http://v.media.daum.net/v/20180911103410467?f=o
# 파이썬 정리 5일차 http://cafe.daum.net/g2G/mHOy/22?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9E%90%EC%8A%B5%EC%84%9C
# 어떻게 무료로 데이터 과학자가 될 수 있는지((주... http://cafe.daum.net/statsas/OE8F/20?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9E%90%EC%8A%B5%EC%84%9C
# 떠오르는 심층 신경망 API, "케라스" 알아보기 http://cafe.daum.net/junnongshield/lpik/23?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9E%90%EC%8A%B5%EC%84%9C
# Genymtn http://cafe.daum.net/synstar/GDuw/3917?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9E%90%EC%8A%B5%EC%84%9C

# %%
# 네이트
for tag in nate.select("div#blogColl .f_link_b"):
    print(tag.text, tag["href"])
# Out:
# [파이썬기초] 자습서 http://jinbonews.tistory.com/8
# 무료 파이썬 자습서, eBook 및 전자책 http://bluebreeze.co.kr/833
# [python][ebook] 귀도의 파이썬 자습서(2.5) (한글 EBook) http://blog.naver.com/PostView.nhn?blogId=dev4unet&logNo=120193065174
# python자습서_ 숫자, 문자열 http://make-it-developer.tistory.com/21

# %% [markdown]
# ## Crawling

# %% [markdown]
# `<a> 태그에 있는 하이퍼링크를 이용해 웹을 인덱싱 하는 작업을 Crawling 이라 합니다.`
#
# 이런 작업을 반복적으로 자동으로 수행하는 Agent를 Bot이라고 합니다.
#
# `Scrapy`는 Agent를 만들어주는 Framework이고, `BeautifulSoup`은 HTML을 Parsing하는 패키지 입니다.<br>
# 실습에서는 `BeautifulSoup`을 사용 합니다.

# %% [markdown]
# ## webscraping.com 사이트에서 Crawling 실습

# %% [markdown]
# - example.webscraping.com/places/default/index 사이트에서 실습하기

# %%
seed = "example.webscraping.com/places/default/index"

# %%
html = getDownload(seed)
dom = BeautifulSoup(html.text, "lxml")

# %%
print(len(dom.select("a")))
# Out:
# 16

# %%
# from urllib.parse import urljoin
from requests.compat import urljoin

urljoin(seed, "/search")
# Out:
# 'http://example.webscraping.com/search'

# %%
for tag in dom.select("a"):
    if tag.has_attr("href"):
        href = tag["href"]
        # print(href)
        
        # URL Normalization
        if href.startswith("http"):    # HTTP(S)
            print("External : {0}".format(href))
        elif href.startswith("/"):
            print(urljoin(seed, href))     # internal link 인 경우 서버 주소를 추가해준다.
        else:
            print("Skipped: {0}".format(href))
# Out:
# Skipped: #
# http://example.webscraping.com/places/default/user/register?_next=/places/default/index
# http://example.webscraping.com/places/default/user/login?_next=/places/default/index
# http://example.webscraping.com/places/default/index
# http://example.webscraping.com/places/default/search
# http://example.webscraping.com/places/default/view/Afghanistan-1
# http://example.webscraping.com/places/default/view/Aland-Islands-2
# http://example.webscraping.com/places/default/view/Albania-3
# http://example.webscraping.com/places/default/view/Algeria-4
# http://example.webscraping.com/places/default/view/American-Samoa-5
# http://example.webscraping.com/places/default/view/Andorra-6
# http://example.webscraping.com/places/default/view/Angola-7
# http://example.webscraping.com/places/default/view/Anguilla-8
# http://example.webscraping.com/places/default/view/Antarctica-9
# http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# http://example.webscraping.com/places/default/index/1

# %%
unseen = []

for tag in dom.select("a"):
    if tag.has_attr("href"):
        href = tag["href"]
        
        # URL Normalization
        if href.startswith("http"):    # HTTP(S)
            print("External : {0}".format(href))
        elif href.startswith("/"):
            newSeed = urljoin(seed, href)
            if newSeed not in unseen:
                unseen.append(newSeed)
        else:
            print("Skipped: {0}".format(href))
    # print(unseen)
# Out:
# Skipped: #

# %% [markdown]
# ### getUrls() 함수 만들기

# %%
def getUrls(base):
    html = getDownload(base)
    dom = BeautifulSoup(html.text, "lxml")
    
    unseen = []

    for tag in dom.select("a"):
        if tag.has_attr("href"):
            href = tag["href"]

            # URL Normalization
            if href.startswith("http"):    # HTTP(S)
                # print("External : {0}".format(href))
                pass
            elif href.startswith("/"):
                newSeed = urljoin(seed, href)
                if newSeed not in unseen:
                    unseen.append(newSeed)
            else:
                # print("Skipped: {0}".format(href))
                pass
                
    print("{0} --> {1}".format(base, len(unseen)))
    
    return unseen

# %%
queue = getUrls(seed)
# Out:
# http://example.webscraping.com/ --> 15

# %%
import time
import random

while queue:
    seed = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
    time.sleep(random.randint(1, 5))
    unseen = getUrls(seed)
# Out:
# http://example.webscraping.com/places/default/user/register?_next=/places/default/index --> 4
# http://example.webscraping.com/places/default/user/login?_next=/places/default/index --> 4
# http://example.webscraping.com/places/default/index --> 15
# http://example.webscraping.com/places/default/search --> 4
# http://example.webscraping.com/places/default/view/Afghanistan-1 --> 12
# http://example.webscraping.com/places/default/view/Aland-Islands-2 --> 7
# http://example.webscraping.com/places/default/view/Albania-3 --> 12
# http://example.webscraping.com/places/default/view/Algeria-4 --> 13
# http://example.webscraping.com/places/default/view/American-Samoa-5 --> 7
# http://example.webscraping.com/places/default/view/Andorra-6 --> 8
# http://example.webscraping.com/places/default/view/Angola-7 --> 10
# http://example.webscraping.com/places/default/view/Anguilla-8 --> 7
# http://example.webscraping.com/places/default/view/Antarctica-9 --> 7
# http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10 --> 7
# http://example.webscraping.com/places/default/index/1 --> 16

# %%
queue = getUrls(seed)

while queue:
    seed = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
    time.sleep(random.randint(1, 5))
    unseen = getUrls(seed)
    
    print("Q:{0}, Unseen:{0}".format(len(queue), len(unseen)))
    queue.extend(unseen)
# Out:
# http://example.webscraping.com/places/default/view/Argentina-11 --> 11
# http://example.webscraping.com/places/default/user/register?_next=/places/default/view/Argentina-11 --> 4
# Q:10, Unseen:10
# http://example.webscraping.com/places/default/user/login?_next=/places/default/view/Argentina-11 --> 4
# Q:13, Unseen:13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-fcae53da02ff> in <module>
#       3 while queue:
#       4     seed = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
# ----> 5     time.sleep(random.randint(1, 5))
#       6     unseen = getUrls(seed)
#       7
#
# KeyboardInterrupt:

# %%
a = [1, 2]
b = [3]
a.append(b)    # list 자체가 추가됨
a
# Out:
# [1, 2, [3]]

# %%
a = [1, 2]
b = [3]
a.extend(b)    # list 원소를 하나 씩 추출해서 추가함
a
# Out:
# [1, 2, 3]

# %%
queue = getUrls(seed)
seen = []

while queue:
    seed = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
    time.sleep(random.randint(1, 5))
    unseen = getUrls(seed)
    
    print("Q:{0}, Unseen:{0}".format(len(queue), len(unseen)))

    queue.extend([link for link in unseen if link not in [seen, queue]])
# Out:
# http://example.webscraping.com/places/default/index --> 15
# http://example.webscraping.com/places/default/user/register?_next=/places/default/index --> 4
# Q:14, Unseen:14
# http://example.webscraping.com/places/default/user/login?_next=/places/default/index --> 4
# Q:17, Unseen:17
# http://example.webscraping.com/places/default/index --> 15
# Q:20, Unseen:20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-1062a69c7845> in <module>
#       4 while queue:
#       5     seed = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
# ----> 6     time.sleep(random.randint(1, 5))
#       7     unseen = getUrls(seed)
#       8
#
# KeyboardInterrupt:

# %% [markdown]
# ## google 검색결과로 부터 External Site Crawling

# %% [markdown]
# ### getUrls() 함수 재정의(1)

# %%
def getUrls(base):
    html = getDownload(base)
    dom = BeautifulSoup(html.text, "lxml")
    
    unseen = []

    for tag in dom.select("a"):
        if tag.has_attr("href"):
            href = tag["href"]

            # URL Normalization
            if href.startswith("http"):    # HTTP(S)
                if href not in unseen:
                    unseen.append(href)

            elif href.startswith("/"):
                newSeed = urljoin(seed, href)
                if newSeed not in unseen:
                    unseen.append(newSeed)
                    
            else:
                # print("Skipped: {0}".format(href))
                pass
                
    print("{0} --> {1}".format(base, len(unseen)))
    
    return unseen

# %%
portalUrl = getPortalSearchUrl()
googleUrl = portalUrl[0]

# %%
html = getDownload(googleUrl, {"q": "파이썬"})
dom = BeautifulSoup(html.text, "lxml")

queue = []

for tag in dom.select(".r > a > h3"):
    href = tag.find_parent()["href"]
    print(tag.text, href)
    queue.append(href)
# Out:
# Welcome to Python.org https://www.python.org/
# 파이썬 자습서 — Python 3.7.2 documentation https://docs.python.org/ko/3/tutorial/index.html
# Python - 나무위키 https://namu.wiki/w/Python
# 파이썬 - 위키백과, 우리 모두의 백과사전 https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC
# 파이썬 입문 | 프로그래머스 https://programmers.co.kr/learn/courses/2
# 01-5 파이썬 둘러보기 - 점프 투 파이썬 - WikiDocs https://wikidocs.net/9
# 1. 파이썬 시작하기 - 왕초보를 위한 Python 2.7 - WikiDocs https://wikidocs.net/43
# 01-2 파이썬의 특징 - 점프 투 파이썬 - WikiDocs https://wikidocs.net/6
# 02-2 문자열 자료형 - 점프 투 파이썬 - WikiDocs https://wikidocs.net/13
# Python & Ruby - 생활코딩 https://opentutorials.org/course/1750

# %%
len(queue), queue
# Out:
# (10,
#  ['https://www.python.org/',
#   'https://docs.python.org/ko/3/tutorial/index.html',
#   'https://namu.wiki/w/Python',
#   'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC',
#   'https://programmers.co.kr/learn/courses/2',
#   'https://wikidocs.net/9',
#   'https://wikidocs.net/43',
#   'https://wikidocs.net/6',
#   'https://wikidocs.net/13',
#   'https://opentutorials.org/course/1750'])

# %%
for link in queue:
    html = getDownload(link)
    dom = BeautifulSoup(html.text, "lxml")
    for a in dom.select("a"):
        if a.has_attr("href"):
            if a["href"].startswith("http"):
                print(a["href"])
            elif a["href"].startswith("/") and len(a["href"]) > 1:
                print(urljoin(link, a["href"]))
            else:
                print("Skipped: {0}".format(a["href"]))
    break
# Out:
# Skipped: #content
# Skipped: #python-network
# Skipped: /
# https://www.python.org/psf-landing/
# https://docs.python.org
# https://pypi.python.org/
# https://www.python.org/jobs/
# https://www.python.org/community/
# Skipped: #top
# Skipped: /
# https://www.python.org/psf/donations/
# Skipped: #site-map
# Skipped: #
# Skipped: javascript:;
# Skipped: javascript:;
# Skipped: javascript:;
# Skipped: #
# https://plus.google.com/+Python
# https://www.facebook.com/pythonlang?fref=ts
# https://twitter.com/ThePSF
# https://www.python.org/community/irc/
# https://www.python.org/about/
# https://www.python.org/about/apps/
# https://www.python.org/about/quotes/
# https://www.python.org/about/gettingstarted/
# https://www.python.org/about/help/
# http://brochure.getpython.info/
# https://www.python.org/downloads/
# https://www.python.org/downloads/
# https://www.python.org/downloads/source/
# https://www.python.org/downloads/windows/
# https://www.python.org/downloads/mac-osx/
# https://www.python.org/download/other/
# https://docs.python.org/3/license.html
# https://www.python.org/download/alternatives
# https://www.python.org/doc/
# https://www.python.org/doc/
# https://www.python.org/doc/av
# https://wiki.python.org/moin/BeginnersGuide
# https://devguide.python.org/
# https://docs.python.org/faq/
# http://wiki.python.org/moin/Languages
# http://python.org/dev/peps/
# https://wiki.python.org/moin/PythonBooks
# https://www.python.org/doc/essays/
# https://www.python.org/community/
# https://www.python.org/community/survey
# https://www.python.org/community/diversity/
# https://www.python.org/community/lists/
# https://www.python.org/community/irc/
# https://www.python.org/community/forums/
# https://www.python.org/community/workshops/
# https://www.python.org/community/sigs/
# https://www.python.org/community/logos/
# https://wiki.python.org/moin/
# https://www.python.org/community/merchandise/
# https://www.python.org/community/awards
# https://www.python.org/psf/codeofconduct/
# https://www.python.org/success-stories/
# https://www.python.org/success-stories/category/arts/
# https://www.python.org/success-stories/category/business/
# https://www.python.org/success-stories/category/education/
# https://www.python.org/success-stories/category/engineering/
# https://www.python.org/success-stories/category/government/
# https://www.python.org/success-stories/category/scientific/
# https://www.python.org/success-stories/category/software-development/
# https://www.python.org/blogs/
# https://www.python.org/blogs/
# http://planetpython.org/
# http://pyfound.blogspot.com/
# http://pycon.blogspot.com/
# https://www.python.org/events/
# https://www.python.org/events/python-events
# https://www.python.org/events/python-user-group/
# https://www.python.org/events/python-events/past/
# https://www.python.org/events/python-user-group/past/
# https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event
# https://www.python.org/shell/
# https://docs.python.org/3/tutorial/controlflow.html#defining-functions
# https://docs.python.org/3/tutorial/introduction.html#lists
# http://docs.python.org/3/tutorial/introduction.html#using-python-as-a-calculator
# https://docs.python.org/3/tutorial/
# https://docs.python.org/3/tutorial/controlflow.html
# https://www.python.org/doc/
# https://www.python.org/about/gettingstarted/
# https://www.python.org/downloads/release/python-372/
# https://docs.python.org
# https://jobs.python.org
# http://blog.python.org
# http://feedproxy.google.com/~r/PythonInsider/~3/Mu9J5e4TQCg/python-357rc1-and-python-3410rc1-are.html
# http://feedproxy.google.com/~r/PythonInsider/~3/Uqm3p_KrtF8/python-2716-released.html
# http://feedproxy.google.com/~r/PythonInsider/~3/c5jWx0k6KrQ/python-380a2-is-now-available-for.html
# http://feedproxy.google.com/~r/PythonSoftwareFoundationNews/~3/gWQmt4BQmN0/the-north-star-of-pycascades-core.html
# http://feedproxy.google.com/~r/PythonInsider/~3/S6j78Cu8CE0/python-2716-release-candidate-1.html
# https://www.python.org/events/calendars/
# https://www.python.org/events/python-user-group/816/
# https://www.python.org/events/python-events/824/
# https://www.python.org/events/python-events/782/
# https://www.python.org/events/python-events/832/
# https://www.python.org/events/python-user-group/836/
# https://www.python.org/success-stories/
# https://www.python.org/success-stories/caldintav-python-for-high-speed-railway-bridges/
# https://www.python.org/success-stories/caldintav-python-for-high-speed-railway-bridges/
# https://www.python.org/about/apps
# http://www.djangoproject.com/
# http://www.pylonsproject.org/
# http://bottlepy.org
# http://tornadoweb.org
# http://flask.pocoo.org/
# http://www.web2py.com/
# http://wiki.python.org/moin/TkInter
# https://wiki.gnome.org/Projects/PyGObject
# http://www.riverbankcomputing.co.uk/software/pyqt/intro
# https://wiki.qt.io/PySide
# https://kivy.org/
# http://www.wxpython.org/
# http://www.scipy.org
# http://pandas.pydata.org/
# http://ipython.org
# http://buildbot.net/
# http://trac.edgewall.org/
# http://roundup.sourceforge.net/
# http://www.ansible.com
# http://www.saltstack.com
# https://www.openstack.org
# https://www.python.org/dev/peps/
# https://www.python.org/dev/peps/peps.rss
# https://www.python.org/psf/
# https://www.python.org/psf/
# https://www.python.org/users/membership/
# https://www.python.org/psf/donations/
# Skipped: #python-network
# https://www.python.org/about/
# https://www.python.org/about/apps/
# https://www.python.org/about/quotes/
# https://www.python.org/about/gettingstarted/
# https://www.python.org/about/help/
# http://brochure.getpython.info/
# https://www.python.org/downloads/
# https://www.python.org/downloads/
# https://www.python.org/downloads/source/
# https://www.python.org/downloads/windows/
# https://www.python.org/downloads/mac-osx/
# https://www.python.org/download/other/
# https://docs.python.org/3/license.html
# https://www.python.org/download/alternatives
# https://www.python.org/doc/
# https://www.python.org/doc/
# https://www.python.org/doc/av
# https://wiki.python.org/moin/BeginnersGuide
# https://devguide.python.org/
# https://docs.python.org/faq/
# http://wiki.python.org/moin/Languages
# http://python.org/dev/peps/
# https://wiki.python.org/moin/PythonBooks
# https://www.python.org/doc/essays/
# https://www.python.org/community/
# https://www.python.org/community/survey
# https://www.python.org/community/diversity/
# https://www.python.org/community/lists/
# https://www.python.org/community/irc/
# https://www.python.org/community/forums/
# https://www.python.org/community/workshops/
# https://www.python.org/community/sigs/
# https://www.python.org/community/logos/
# https://wiki.python.org/moin/
# https://www.python.org/community/merchandise/
# https://www.python.org/community/awards
# https://www.python.org/psf/codeofconduct/
# https://www.python.org/success-stories/
# https://www.python.org/success-stories/category/arts/
# https://www.python.org/success-stories/category/business/
# https://www.python.org/success-stories/category/education/
# https://www.python.org/success-stories/category/engineering/
# https://www.python.org/success-stories/category/government/
# https://www.python.org/success-stories/category/scientific/
# https://www.python.org/success-stories/category/software-development/
# https://www.python.org/blogs/
# https://www.python.org/blogs/
# http://planetpython.org/
# http://pyfound.blogspot.com/
# http://pycon.blogspot.com/
# https://www.python.org/events/
# https://www.python.org/events/python-events
# https://www.python.org/events/python-user-group/
# https://www.python.org/events/python-events/past/
# https://www.python.org/events/python-user-group/past/
# https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event
# https://www.python.org/dev/
# https://devguide.python.org/
# https://bugs.python.org/
# https://mail.python.org/mailman/listinfo/python-dev
# https://www.python.org/dev/core-mentorship/
# https://www.python.org/news/security/
# Skipped: #python-network
# https://www.python.org/about/help/
# https://www.python.org/community/diversity/
# https://github.com/python/pythondotorg/issues
# https://status.python.org/
# https://www.python.org/psf-landing/
# https://www.python.org/about/legal/
# https://www.python.org/privacy/
# https://www.python.org/psf/sponsorship/sponsors/#heroku

# %%
for link in queue:
    links = []
    html = getDownload(link)
    dom = BeautifulSoup(html.text, "lxml")
    for a in dom.select("a"):
        if a.has_attr("href"):
            if a["href"].startswith("http"):
                links.append(a["href"])
            elif a["href"].startswith("/") and len(a["href"]) > 1:
                links.append(urljoin(link, a["href"]))
            else:
                pass
                # print("Skipped: {0}".format(a["href"]))
    print("{0} --> {1}".format(link, len(links)))
# Out:
# https://www.python.org/ --> 190
# https://docs.python.org/ko/3/tutorial/index.html --> 6
# https://namu.wiki/w/Python --> 417
# https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 499
# https://programmers.co.kr/learn/courses/2 --> 161
# https://wikidocs.net/9 --> 6
# https://wikidocs.net/43 --> 4
# https://wikidocs.net/6 --> 7
# https://wikidocs.net/13 --> 8
# https://opentutorials.org/course/1750 --> 144

# %% [markdown]
# ### getUrls() 함수 재정의(2)

# %%
def getUrls(link, depth=3):
    if depth > 3:
        return None
    
    links = []
    html = getDownload(link)
    dom = BeautifulSoup(html.text, "lxml")

    for a in dom.select("a"):
        if a.has_attr("href"):
            if a["href"].startswith("http"):
                links.append({"url": a["href"], "depth": depth+1})
            elif a["href"].startswith("/") and len(a["href"]) > 1:
                links.append({"url": urljoin(link, a["href"]), "depth": depth+1})
            else:
                pass
                # print("Skipped: {0}".format(a["href"]))
    print("{0} {1} -> {2}".format(">" * (depth+1), link, len(links)))
        
    return links

# %%
html = getDownload(googleUrl, {"q": "파이썬"})
dom = BeautifulSoup(html.text, "lxml")

# %%
queue = []

for tag in dom.select(".r > a > h3"):
    href = tag.find_parent()["href"]
    queue.append({"url": href, "depth": 0})

# %%
queue
# Out:
# [{'url': 'https://www.python.org/', 'depth': 0},
#  {'url': 'https://docs.python.org/ko/3/tutorial/index.html', 'depth': 0},
#  {'url': 'https://namu.wiki/w/Python', 'depth': 0},
#  {'url': 'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC',
#   'depth': 0},
#  {'url': 'https://programmers.co.kr/learn/courses/2', 'depth': 0},
#  {'url': 'https://wikidocs.net/43', 'depth': 0},
#  {'url': 'https://wikidocs.net/9', 'depth': 0},
#  {'url': 'https://wikidocs.net/6', 'depth': 0},
#  {'url': 'https://wikidocs.net/13', 'depth': 0},
#  {'url': 'https://opentutorials.org/course/1750', 'depth': 0}]

# %%
while queue:
    link = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
    links = getUrls(link["url"], link["depth"])
    
    if links != None:
        for newlink in links:
            if newlink not in queue:
                queue.append(newlink)
# Out:
# > https://www.python.org/ --> 0개 사이트 추가
# > https://www.python.org/ --> 0개 사이트 추가
# > https://www.python.org/ --> 1개 사이트 추가
# > https://www.python.org/ --> 2개 사이트 추가
# > https://www.python.org/ --> 3개 사이트 추가
# > https://www.python.org/ --> 4개 사이트 추가
# > https://www.python.org/ --> 5개 사이트 추가
# > https://www.python.org/ --> 6개 사이트 추가
# > https://www.python.org/ --> 6개 사이트 추가
# > https://www.python.org/ --> 7개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 8개 사이트 추가
# > https://www.python.org/ --> 9개 사이트 추가
# > https://www.python.org/ --> 10개 사이트 추가
# > https://www.python.org/ --> 11개 사이트 추가
# > https://www.python.org/ --> 12개 사이트 추가
# > https://www.python.org/ --> 13개 사이트 추가
# > https://www.python.org/ --> 14개 사이트 추가
# > https://www.python.org/ --> 15개 사이트 추가
# > https://www.python.org/ --> 16개 사이트 추가
# > https://www.python.org/ --> 17개 사이트 추가
# > https://www.python.org/ --> 18개 사이트 추가
# > https://www.python.org/ --> 19개 사이트 추가
# > https://www.python.org/ --> 20개 사이트 추가
# > https://www.python.org/ --> 21개 사이트 추가
# > https://www.python.org/ --> 22개 사이트 추가
# > https://www.python.org/ --> 23개 사이트 추가
# > https://www.python.org/ --> 24개 사이트 추가
# > https://www.python.org/ --> 25개 사이트 추가
# > https://www.python.org/ --> 26개 사이트 추가
# > https://www.python.org/ --> 27개 사이트 추가
# > https://www.python.org/ --> 28개 사이트 추가
# > https://www.python.org/ --> 29개 사이트 추가
# > https://www.python.org/ --> 30개 사이트 추가
# > https://www.python.org/ --> 31개 사이트 추가
# > https://www.python.org/ --> 32개 사이트 추가
# > https://www.python.org/ --> 33개 사이트 추가
# > https://www.python.org/ --> 34개 사이트 추가
# > https://www.python.org/ --> 35개 사이트 추가
# > https://www.python.org/ --> 36개 사이트 추가
# > https://www.python.org/ --> 37개 사이트 추가
# > https://www.python.org/ --> 38개 사이트 추가
# > https://www.python.org/ --> 39개 사이트 추가
# > https://www.python.org/ --> 40개 사이트 추가
# > https://www.python.org/ --> 41개 사이트 추가
# > https://www.python.org/ --> 42개 사이트 추가
# > https://www.python.org/ --> 43개 사이트 추가
# > https://www.python.org/ --> 44개 사이트 추가
# > https://www.python.org/ --> 45개 사이트 추가
# > https://www.python.org/ --> 46개 사이트 추가
# > https://www.python.org/ --> 47개 사이트 추가
# > https://www.python.org/ --> 48개 사이트 추가
# > https://www.python.org/ --> 49개 사이트 추가
# > https://www.python.org/ --> 50개 사이트 추가
# > https://www.python.org/ --> 51개 사이트 추가
# > https://www.python.org/ --> 52개 사이트 추가
# > https://www.python.org/ --> 53개 사이트 추가
# > https://www.python.org/ --> 54개 사이트 추가
# > https://www.python.org/ --> 55개 사이트 추가
# > https://www.python.org/ --> 56개 사이트 추가
# > https://www.python.org/ --> 57개 사이트 추가
# > https://www.python.org/ --> 58개 사이트 추가
# > https://www.python.org/ --> 59개 사이트 추가
# > https://www.python.org/ --> 60개 사이트 추가
# > https://www.python.org/ --> 61개 사이트 추가
# > https://www.python.org/ --> 62개 사이트 추가
# > https://www.python.org/ --> 63개 사이트 추가
# > https://www.python.org/ --> 64개 사이트 추가
# > https://www.python.org/ --> 65개 사이트 추가
# > https://www.python.org/ --> 66개 사이트 추가
# > https://www.python.org/ --> 67개 사이트 추가
# > https://www.python.org/ --> 68개 사이트 추가
# > https://www.python.org/ --> 69개 사이트 추가
# > https://www.python.org/ --> 70개 사이트 추가
# > https://www.python.org/ --> 71개 사이트 추가
# > https://www.python.org/ --> 72개 사이트 추가
# > https://www.python.org/ --> 73개 사이트 추가
# > https://www.python.org/ --> 74개 사이트 추가
# > https://www.python.org/ --> 75개 사이트 추가
# > https://www.python.org/ --> 76개 사이트 추가
# > https://www.python.org/ --> 77개 사이트 추가
# > https://www.python.org/ --> 78개 사이트 추가
# > https://www.python.org/ --> 79개 사이트 추가
# > https://www.python.org/ --> 80개 사이트 추가
# > https://www.python.org/ --> 81개 사이트 추가
# > https://www.python.org/ --> 82개 사이트 추가
# > https://www.python.org/ --> 83개 사이트 추가
# > https://www.python.org/ --> 84개 사이트 추가
# > https://www.python.org/ --> 85개 사이트 추가
# > https://www.python.org/ --> 86개 사이트 추가
# > https://www.python.org/ --> 87개 사이트 추가
# > https://www.python.org/ --> 88개 사이트 추가
# > https://www.python.org/ --> 89개 사이트 추가
# > https://www.python.org/ --> 90개 사이트 추가
# > https://www.python.org/ --> 91개 사이트 추가
# > https://www.python.org/ --> 92개 사이트 추가
# > https://www.python.org/ --> 93개 사이트 추가
# > https://www.python.org/ --> 94개 사이트 추가
# > https://www.python.org/ --> 95개 사이트 추가
# > https://www.python.org/ --> 96개 사이트 추가
# > https://www.python.org/ --> 97개 사이트 추가
# > https://www.python.org/ --> 98개 사이트 추가
# > https://www.python.org/ --> 99개 사이트 추가
# > https://www.python.org/ --> 100개 사이트 추가
# > https://www.python.org/ --> 101개 사이트 추가
# > https://www.python.org/ --> 102개 사이트 추가
# > https://www.python.org/ --> 103개 사이트 추가
# > https://www.python.org/ --> 104개 사이트 추가
# > https://www.python.org/ --> 105개 사이트 추가
# > https://www.python.org/ --> 106개 사이트 추가
# > https://www.python.org/ --> 107개 사이트 추가
# > https://www.python.org/ --> 108개 사이트 추가
# > https://www.python.org/ --> 109개 사이트 추가
# > https://www.python.org/ --> 110개 사이트 추가
# > https://www.python.org/ --> 111개 사이트 추가
# > https://www.python.org/ --> 112개 사이트 추가
# > https://www.python.org/ --> 113개 사이트 추가
# > https://www.python.org/ --> 114개 사이트 추가
# > https://www.python.org/ --> 115개 사이트 추가
# > https://www.python.org/ --> 116개 사이트 추가
# > https://www.python.org/ --> 117개 사이트 추가
# > https://www.python.org/ --> 118개 사이트 추가
# > https://www.python.org/ --> 119개 사이트 추가
# > https://www.python.org/ --> 120개 사이트 추가
# > https://www.python.org/ --> 121개 사이트 추가
# > https://www.python.org/ --> 122개 사이트 추가
# > https://www.python.org/ --> 122개 사이트 추가
# > https://www.python.org/ --> 123개 사이트 추가
# > https://www.python.org/ --> 124개 사이트 추가
# > https://www.python.org/ --> 125개 사이트 추가
# > https://www.python.org/ --> 126개 사이트 추가
# > https://www.python.org/ --> 127개 사이트 추가
# > https://www.python.org/ --> 128개 사이트 추가
# > https://www.python.org/ --> 129개 사이트 추가
# > https://www.python.org/ --> 130개 사이트 추가
# > https://www.python.org/ --> 131개 사이트 추가
# > https://www.python.org/ --> 132개 사이트 추가
# > https://www.python.org/ --> 133개 사이트 추가
# > https://www.python.org/ --> 134개 사이트 추가
# > https://www.python.org/ --> 135개 사이트 추가
# > https://www.python.org/ --> 136개 사이트 추가
# > https://www.python.org/ --> 137개 사이트 추가
# > https://www.python.org/ --> 138개 사이트 추가
# > https://www.python.org/ --> 139개 사이트 추가
# > https://www.python.org/ --> 140개 사이트 추가
# > https://www.python.org/ --> 141개 사이트 추가
# > https://www.python.org/ --> 142개 사이트 추가
# > https://www.python.org/ --> 143개 사이트 추가
# > https://www.python.org/ --> 144개 사이트 추가
# > https://www.python.org/ --> 145개 사이트 추가
# > https://www.python.org/ --> 146개 사이트 추가
# > https://www.python.org/ --> 147개 사이트 추가
# > https://www.python.org/ --> 148개 사이트 추가
# > https://www.python.org/ --> 149개 사이트 추가
# > https://www.python.org/ --> 150개 사이트 추가
# > https://www.python.org/ --> 151개 사이트 추가
# > https://www.python.org/ --> 152개 사이트 추가
# > https://www.python.org/ --> 153개 사이트 추가
# > https://www.python.org/ --> 154개 사이트 추가
# > https://www.python.org/ --> 155개 사이트 추가
# > https://www.python.org/ --> 156개 사이트 추가
# > https://www.python.org/ --> 157개 사이트 추가
# > https://www.python.org/ --> 158개 사이트 추가
# > https://www.python.org/ --> 159개 사이트 추가
# > https://www.python.org/ --> 160개 사이트 추가
# > https://www.python.org/ --> 161개 사이트 추가
# > https://www.python.org/ --> 162개 사이트 추가
# > https://www.python.org/ --> 163개 사이트 추가
# > https://www.python.org/ --> 164개 사이트 추가
# > https://www.python.org/ --> 165개 사이트 추가
# > https://www.python.org/ --> 166개 사이트 추가
# > https://www.python.org/ --> 167개 사이트 추가
# > https://www.python.org/ --> 168개 사이트 추가
# > https://www.python.org/ --> 169개 사이트 추가
# > https://www.python.org/ --> 170개 사이트 추가
# > https://www.python.org/ --> 171개 사이트 추가
# > https://www.python.org/ --> 172개 사이트 추가
# > https://www.python.org/ --> 173개 사이트 추가
# > https://www.python.org/ --> 174개 사이트 추가
# > https://www.python.org/ --> 175개 사이트 추가
# > https://www.python.org/ --> 176개 사이트 추가
# > https://www.python.org/ --> 177개 사이트 추가
# > https://www.python.org/ --> 178개 사이트 추가
# > https://www.python.org/ --> 179개 사이트 추가
# > https://www.python.org/ --> 180개 사이트 추가
# > https://www.python.org/ --> 181개 사이트 추가
# > https://www.python.org/ --> 182개 사이트 추가
# > https://www.python.org/ --> 183개 사이트 추가
# > https://www.python.org/ --> 184개 사이트 추가
# > https://www.python.org/ --> 184개 사이트 추가
# > https://www.python.org/ --> 185개 사이트 추가
# > https://www.python.org/ --> 186개 사이트 추가
# > https://www.python.org/ --> 187개 사이트 추가
# > https://www.python.org/ --> 188개 사이트 추가
# > https://www.python.org/ --> 189개 사이트 추가
# > https://www.python.org/ --> 190개 사이트 추가
# > https://www.python.org/ --> 191개 사이트 추가
# > https://www.python.org/ --> 192개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 0개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 0개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 0개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 0개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 1개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 1개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 1개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 2개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 3개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 3개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 3개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 3개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 3개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 4개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 4개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 4개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 5개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 5개 사이트 추가
# > https://docs.python.org/ko/3/tutorial/index.html --> 6개 사이트 추가
# HTTPError:[429]:Too Many Requests, {'Date': 'Tue, 12 Mar 2019 04:57:51 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d71a873fceacc962447402629dee663f71552366671; expires=Wed, 11-Mar-20 04:57:51 GMT; path=/; domain=.namu.wiki; HttpOnly; Secure', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Expires': '-1', 'Pragma': 'no-cache', 'Retry-After': '3600', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '4b6330924ece128b-ICN'}
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 0개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 0개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 0개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 1개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 2개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 3개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 4개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 5개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 6개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 7개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 8개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 9개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 10개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 11개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 12개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 13개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 14개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 15개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 16개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 17개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 18개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 19개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 20개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 21개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 22개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 23개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 24개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 25개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 26개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 27개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 28개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 29개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 30개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 31개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 32개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 33개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 34개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 35개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 36개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 37개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 38개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 39개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 40개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 41개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 42개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 43개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 44개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 45개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 46개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 47개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 48개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 49개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 50개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 51개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 51개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 52개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 53개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 53개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 54개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 55개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 55개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 56개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 57개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 58개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 59개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 60개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 61개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 62개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 63개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 64개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 65개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 66개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 67개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 68개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 69개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 70개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 71개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 72개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 73개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 74개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 75개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 76개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 77개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 78개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 79개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 80개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 81개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 82개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 83개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 84개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 85개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 86개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 87개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 88개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 89개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 90개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 91개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 92개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 93개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 94개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 95개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 95개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 96개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 97개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 98개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 99개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 100개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 101개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 101개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 101개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 102개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 103개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 104개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 105개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 106개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 107개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 107개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 108개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 109개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 110개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 111개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 112개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 113개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 114개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 115개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 116개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 117개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 118개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 119개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 120개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 121개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 122개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 123개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 124개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 125개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 126개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 127개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 128개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 129개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 130개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 131개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 132개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 133개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 134개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 135개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 136개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 137개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 138개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 139개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 140개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 141개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 142개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 143개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 144개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 145개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 146개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 147개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 148개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 149개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 150개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 151개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 152개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 153개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 154개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 155개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 156개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 157개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 158개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 159개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 160개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 161개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 162개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 163개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 164개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 165개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 166개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 167개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 168개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 169개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 170개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 171개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 172개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 173개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 174개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 175개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 176개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 177개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 178개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 179개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 180개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 181개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 182개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 183개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 184개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 185개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 186개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 187개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 188개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 189개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 189개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 189개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 190개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 191개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 192개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 193개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 193개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 194개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 195개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 195개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 196개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 197개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 198개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 198개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 199개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 199개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 200개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 201개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 202개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 203개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 204개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 205개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 206개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 207개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 207개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 208개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 208개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 209개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 209개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 210개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 210개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 211개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 211개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 212개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 213개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 214개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 215개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 216개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 217개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 218개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 219개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 220개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 221개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 221개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 222개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 223개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 224개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 225개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 226개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 227개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 228개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 229개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 230개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 231개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 232개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 233개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 234개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 235개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 236개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 237개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 238개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 239개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 240개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 241개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 242개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 243개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 244개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 245개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 246개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 247개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 248개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 249개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 250개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 251개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 252개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 253개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 254개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 255개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 256개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 257개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 258개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 259개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 260개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 261개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 262개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 263개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 264개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 265개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 266개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 267개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 268개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 269개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 269개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 270개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 271개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 272개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 273개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 274개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 275개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 276개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 277개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 278개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 279개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 280개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 281개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 282개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 283개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 284개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 285개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 286개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 287개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 288개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 289개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 290개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 291개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 292개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 293개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 294개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 295개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 296개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 297개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 298개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 299개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 300개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 301개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 302개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 303개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 304개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 305개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 306개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 307개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 308개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 309개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 310개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 311개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 312개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 313개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 314개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 315개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 316개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 317개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 318개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 319개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 320개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 321개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 322개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 323개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 324개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 324개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 325개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 326개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 327개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 328개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 329개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 330개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 331개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 332개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 333개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 334개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 335개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 336개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 337개 사이트 추가
# > https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC --> 338개 사이트 추가
# ...
# >> https://www.python.org/about/gettingstarted/ --> 0개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 0개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 1개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 2개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 3개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 4개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 5개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 6개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 6개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 7개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 8개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 9개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 10개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 11개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 12개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 13개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 14개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 15개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 16개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 17개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 18개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 19개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 20개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 21개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 22개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 23개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 24개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 25개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 26개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 27개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 28개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 29개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 30개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 31개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 32개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 33개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 34개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 35개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 36개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 37개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 38개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 39개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 40개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 41개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 42개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 43개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 44개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 45개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 46개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 47개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 48개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 49개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 50개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 51개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 52개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 53개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 54개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 55개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 56개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 57개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 58개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 59개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 60개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 61개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 62개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 63개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 64개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 65개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 66개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 67개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 68개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 69개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 70개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 71개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 72개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 73개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 74개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 75개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 76개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 77개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 78개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 79개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 80개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 81개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 82개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 83개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 84개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 85개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 86개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 87개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 87개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 88개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 89개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 90개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 90개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 91개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 92개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 93개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 94개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 95개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 96개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 97개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 98개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 99개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 100개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 101개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 102개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 103개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 104개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 105개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 106개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 107개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 108개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 109개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 110개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 111개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 112개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 113개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 114개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 115개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 116개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 117개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 118개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 119개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 120개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 121개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 122개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 123개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 124개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 125개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 126개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 127개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 128개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 129개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 130개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 131개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 132개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 133개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 134개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 135개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 136개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 137개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 138개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 139개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 140개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 141개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 142개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 143개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 144개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 145개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 146개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 147개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 148개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 149개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 150개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 151개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 152개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 152개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 153개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 154개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 155개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 156개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 157개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 158개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 159개 사이트 추가
# >> https://www.python.org/about/gettingstarted/ --> 160개 사이트 추가
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-11fc6489d5f5> in <module>
#       1 while queue:
#       2     link = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
# ----> 3     links = getUrls(link["url"], link["depth"])
#       4
#       5     if links != None:
#
# ~/Documents/ai/NLP/nlp_ipa/functions/crawling.py in getUrls(link, depth)
#      22     links = []
#      23
# ---> 24     html = getDownload(link)
#      25     dom = BeautifulSoup(html.text, "lxml")
#      26
#
# ~/Documents/ai/NLP/nlp_ipa/functions/download.py in getDownload(url, params, headers, retries)
#      34
#      35     try:
# ---> 36         resp = requests.get(url, params=params, headers=headers)
#      37         resp.raise_for_status()
#      38     except HTTPError as e:
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:

# %% [markdown]
# ### crawling 함수를 사용

# %%
from functions import crawling
from functions.crawling import getUrls

# %%
html = getDownload(googleUrl, {"q": "파이썬"})
dom = BeautifulSoup(html.text, "lxml")

# %%
queue = []

for tag in dom.select(".r > a > h3"):
    href = tag.find_parent()["href"]
    queue.append({"url": href, "depth": 0})

# %%
queue
# Out:
# [{'url': 'https://www.python.org/', 'depth': 0},
#  {'url': 'https://docs.python.org/ko/3/tutorial/index.html', 'depth': 0},
#  {'url': 'https://namu.wiki/w/Python', 'depth': 0},
#  {'url': 'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC',
#   'depth': 0},
#  {'url': 'https://programmers.co.kr/learn/courses/2', 'depth': 0},
#  {'url': 'https://wikidocs.net/43', 'depth': 0},
#  {'url': 'https://wikidocs.net/9', 'depth': 0},
#  {'url': 'https://wikidocs.net/6', 'depth': 0},
#  {'url': 'https://wikidocs.net/13', 'depth': 0},
#  {'url': 'https://opentutorials.org/course/1750', 'depth': 0}]

# %%
seen = []

while queue:
    unseen = []
    seed = queue.pop(0)    # 맨 앞에 있는 것을 가져옴
    seen.append(seed)
    time.sleep(random.randint(1, 3))
    unseen = getUrls(seed["url"], seed["depth"])
    
    print("Queue:{0}, Unseen:{0}".format(len(queue), len(unseen)))

    queue.extend([{link["url"], link["depth"]} for link in unseen if link not in seen and queue])
# Out:
# > https://wikidocs.net/6 --> 9개 사이트 추가
# Queue:867, Unseen:867
# > https://wikidocs.net/13 --> 10개 사이트 추가
# Queue:875, Unseen:875
# > https://opentutorials.org/course/1750 --> 144개 사이트 추가
# Queue:884, Unseen:884
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d2f61f2b9abc> in <module>
#       6     seen.append(seed)
#       7     time.sleep(random.randint(1, 3))
# ----> 8     unseen = getUrls(seed["url"], seed["depth"])
#       9
#      10     print("Queue:{0}, Unseen:{0}".format(len(queue), len(unseen)))
#
# TypeError: 'set' object is not subscriptable
