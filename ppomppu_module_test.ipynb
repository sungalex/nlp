# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#뽐뿌게시판-scraping" data-toc-modified-id="뽐뿌게시판-scraping-1">뽐뿌게시판 scraping</a></span></li></ul></div>

# %% [markdown]
# ## 뽐뿌게시판 scraping

# %% [markdown]
# - http://www.ppomppu.co.kr/zboard/zboard.php?id=ppomppu
# - functions.ppomppu.py 모듈의 뽐뿌게시판 scraping 관련 함수를 테스트 합니다.

# %%
from functions.ppomppu import Ppomppu
from functions.download import getDownload
from bs4 import BeautifulSoup

# %%
# Ppomppu 객체
# 숫자로 카테고리를 지정 가능(지정하지 않으면 전체 검색)
# 1:기타, 4~6:컴퓨터/디니털/먹거리, 8~13:서적/가전가구/육아/카메라/의류잡화/화장품, 15:등산캠핑
bbs = Ppomppu()
# ppomppu.Ppomppu(4)

# %%
dom = bbs.bs   # BeautifulSoup 객체

# %%
# 번호
bbs.getNumbers()
# Out:
# ['311612',
#  '311611',
#  '311610',
#  '311609',
#  '311608',
#  '311607',
#  '311605',
#  '311604',
#  '311603',
#  '311602',
#  '311601',
#  '311600',
#  '311599',
#  '311598',
#  '311597',
#  '311596',
#  '311595',
#  '311594',
#  '311593',
#  '311592']

# %%
# 분류
bbs.getCategorys()
# Out:
# ['화장품',
#  '컴퓨터',
#  '기타',
#  '디지털',
#  '기타',
#  '먹을거리',
#  '기타',
#  '먹을거리',
#  '의류/잡화',
#  '먹을거리',
#  '의류/잡화',
#  '기타',
#  '기타',
#  '컴퓨터',
#  '기타',
#  '기타',
#  '디지털',
#  '디지털',
#  '의류/잡화',
#  '의류/잡화']

# %%
# 글쓴이
bbs.getWriters()
# Out:
# ['가보즈아!',
#  '경아아버지',
#  '변소',
#  '김소현',
#  '당신의지갑에구멍을',
#  '비타민원츄',
#  '루어루어',
#  'best1985',
#  '사기치지말자',
#  '르르랑',
#  '루이렉스',
#  'γ^^γ가든~♡',
#  '하진제',
#  'braydlgt',
#  '웰컴이다',
#  '샤프1004',
#  '초로롱초롱',
#  'ARIUM',
#  '감지기',
#  '백묘s']

# %%
# 게시글 제목
bbs.getTitles()
# Out:
# ['[위메프] 미샤 아쿠아 펩타이드 크림 4개 (11,333원/ 무료) 수분크림or 바디용 핸드크림용 추천',
#  '[G마켓] ACER TMX514-51 i5 트래블메이트 586C (969,000 / 무배)',
#  '[플레이스토어] Photo Editor Pro – Filters, Sticker (한시적무료 / 무료)',
#  '[티몬] 모즈온 9v 급속 무선충전 거치대 (8,900 / 무료)',
#  '[티몬] 동원 다방커피 250ml×12개 오리지널/헤이즐넛 (7,900원/무료배송)',
#  '[티몬] GS25 편의점 모바일 상품권 1만원권 (8,900원/무료) 적립금 사용 가능',
#  '[Gs shop] 젤클리너 (2820원/ 무료)',
#  '[정원e샵] 청정원 안주야 불족발&껍데기180gx3개 / 정원 클래식가입자만 가성비 있음 (16,900/2,500)',
#  '[티몬] 트렉스타 남녀 트레킹화 4종 (10,500원/무료)',
#  '[G마켓] IP010-X Pro 알리캡슐 블루투스 무선 이어폰 (25,700/무배)',
#  '[위메프] ASUS 게이밍 노트북 TUF FX505GM-BQ234 (1,199,000원 -> 모든 할인/적립 적용 시 1,064,500원/무료)',
#  '[11번가] 헤드앤숄더 신상/베스트 850mlX3+풋볼타월+샘플80mlx2개 (쿠폰가 17,180 / 무료배송)',
#  '[G마켓]험멜 쉐브론 트랙수트 3종(43,590/무료)']

# %%
# 게시글 본문 링크
bbs.getLinks()
# Out:
# ['http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311612',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311611',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311610',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311609',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311607',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311605',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311603',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311602',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311601',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311600',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311598',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311597',
#  'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311592']

# %%
# 게시글 이미지(섬네일) 링크
bbs.getImageLinks()
# Out:
# ['http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/2/small_311612.jpg?t=20190314013350',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/1/small_311611.jpg?t=20190314013148',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/0/small_311610.jpg?t=20190314012845',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/9/small_311609.jpg?t=20190314003233',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/8/small_311608.jpg?t=20190314002244',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/7/small_311607.jpg?t=20190313235950',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/5/small_311605.jpg?t=20190314000138',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/4/small_311604.jpg?t=20190313235327',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/3/small_311603.jpg?t=20190313232649',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/2/small_311602.jpg?t=20190313224720',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/1/small_311601.jpg?t=20190313222336',
#  'http://static.ppomppu.co.kr/www/img/noimage/noimage_60x50.jpg',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/9/small_311599.jpg?t=20190313213547',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/8/small_311598.jpg?t=20190313212923',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/7/small_311597.jpg?t=20190313204210',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/6/small_311596.jpg?t=20190313211840',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/5/small_311595.jpg?t=20190313202512',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/4/small_311594.jpg?t=20190313202330',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/3/small_311593.jpg?t=20190313194948',
#  'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/2/small_311592.jpg?t=20190313191252']

# %%
# 게시글 이미지(섬네일) 파일 다운로드 후 저장된 파일 리스트 반환
bbs.getImages()
# Out:
# ['images/ppompu/2019-03-14_01-39/small_311612.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311611.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311610.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311609.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311608.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311607.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311605.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311604.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311603.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311602.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311601.jpg',
#  'images/ppompu/2019-03-14_01-39/noimage_60x50.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311599.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311598.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311597.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311596.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311595.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311594.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311593.jpg',
#  'images/ppompu/2019-03-14_01-39/small_311592.jpg']

# %%
# 댓글 수
bbs.getReplyCounts()
# Out:
# [0, 0, 0, 7, 13, 14, 20, 46, 28, 63, 15, 76, 81]

# %%
# 게시글 등록일
bbs.getWriteDates()
# Out:
# ['13.10.24 13:24:54',
#  '19.03.14 01:36:11',
#  '19.03.14 01:35:41',
#  '19.03.14 01:32:38',
#  '19.03.14 00:33:35',
#  '19.03.14 00:24:52',
#  '19.03.14 00:03:42',
#  '19.03.14 00:01:04',
#  '19.03.13 23:56:57',
#  '19.03.13 23:29:48',
#  '19.03.13 22:44:17',
#  '19.03.13 22:27:28',
#  '19.03.13 22:01:19',
#  '19.03.13 21:36:06',
#  '19.03.13 21:33:15',
#  '19.03.13 20:46:03',
#  '19.03.13 20:42:41',
#  '19.03.13 20:29:05',
#  '19.03.13 20:21:21',
#  '19.03.13 19:53:40',
#  '19.03.13 19:16:44']

# %%
# 게시글 추천수
bbs.getLikeCounts()
# Out:
# [0, 0, 0, 1, 0, 3, 27, 0, 8, 7, 4, 13, 4, 0, 25, 10, 5, 5, 1, 35]

# %%
# 게시글 조회수
bbs.getQueryCounts()
# Out:
# [40,
#  73,
#  362,
#  2488,
#  2600,
#  2197,
#  3553,
#  1233,
#  6507,
#  4856,
#  8140,
#  13434,
#  3233,
#  4453,
#  9523,
#  10664,
#  12556,
#  20387,
#  9206,
#  25121]

# %%
# 게시글 본문
contents = bbs.getContentBodys()
for content in contents:
    print(content)
    print(">" * 50, end="\n\n")
# Out:
# 화장품은 고가 저가 할것 없이
#
#
#
# 성분이 중요하다고 해서, 화장품 성분앱 자주 봅니다
#
# 성분 구성은 순하고 좋으나 인기 상품은 아닌지라
# 위메프 행사로 떨이하는것 같습니다
#
# 종류는 66과 99 두가지이고,
# 유분감에 따른 사용감 차이로 보이구요
#
# 보통 로션 정도 66
# 좀더 유분끼+ 크림느낌 99 가심 될거 같습니다
#
# 얼굴용 무난한 로션대용으로 쓰셔도 되고
# 저같은 경우는 핸드크림 바디크림으로 사용합니다
#
# 50ml씩 4개라 하나씩 사무실 헬스장 두고 후뚜루마뚜루 쓰기 좋을것 같습니다~!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 저는 1년 전쯤 구매한 ACER 스위프트3(SF314-52) 사용자입니다.
# 에이서... 지금 사용하는게 처음이지만 참 좋은데 뭐라 표현할 방법이 없네요.
# 현재 가성비 가심비 모두 매우 만족하며 사용 중입니다
#
#
#
# 이 글을 쓰게된 이유는 얼마 전 스위프트3의 상위 시리즈인 스위프트5의 뽐뿌 글을 봤는데 (지금 보니 삭제됐네요;;;)
# 몇몇 분이 이걸 사느니 몇십 더 주더라도 차라리 LG 그램을 사겠다는 말씀을 하시는 걸 보고
# 에이서 사용자로서 마음이 아팠다가... 문득!!
# 이 정도 퀄리티에 비슷한 스펙이면 LG와 ACER는 가격차이가 얼마나 날까 하는 생각이 들어 찾아서 비교를 해봤습니다!!!
# 윈도우가 없는 모델이면 더 좋겠다 하는 댓글을 본 것 같아서 윈도 없는 걸로 찾아봤는데... 있었습니다!!!
# 트래블메이트(?) TMX514 라는 모델인데 리뷰를 꼼꼼히 읽어보니 스위프트5와 거의 동일한 것 같습니다.
# 게다가 무게는 더 가볍고 패널도 무광이네요.
# 아무튼 이 모델과 동일하게 윈도가 설치되어 있지 않으면서 인기순위 제일 상위에 있는 LG 14그램과 비교해봤습니다.
# 보시죠!!! 두둥!!!
#
#
#
#
# 제조사
# ACER
# 비교
# LG
#
#
# 모델명
# TMX514-51 i5
#
# 14ZD990-GX50K
#
#
# CPU
# i5-8265U
# =
# i5-8265U
#
#
# RAM
# 8GB
# =
# 8GB
#
#
# SSD
# M.2 NVMe 256GB
# >
# M.2 256GB
#
#
# LCD
# 14.0" IPS
# =
# 14.0" IPS
#
#
# 운영체제
# LINUX
# =
# Free DOS
#
#
# 색상
# 블랙
# 취향
# 화이트
#
#
# 크기
# 329 x 228 x 14.9 mm
# =
#
# 323 x 212 x
#   16.5 mm
#
#
#
# 재질
# 메탈 (리튬-마그네슘?)
# =
# 메탈 (마그네슘 합금?)
#
#
# 배터리
# 리튬 이온(4670mAh)
# <
#
# 리튬 폴리머(???)
#
#
#
# 무게
#
# 935g
#
# >
# 995g
#
#
# 업그레이드
#
# RAM
#   추가 불가
# M.2(NVMe) SSD 추가 가능
#
# <
#
#
# RAM 추가 가능
#
#
# M.2 SSD 추가 가능
#
#
#
#
# 사은품
#
# MS
#   디자이너
# 블루투스마스
#
# 취향
# 마우스,패드,키스킨,오피스
#
#
# A/S
# 에이씨...ER
# <<<
#
# LG
#
#
#
#
# 인터넷
# 최저가
# (3/13기준)
#
#
# 969,000
#
# >
# 1,387,000
#
#
#
# 구매가능
# 최저가
# (3/13기준)
#
#
# 919,000
#
# >
# 1,338,000
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 사진편집기 어플이 한시적 무료로 풀려있네요
# 2일남았다고합니다. 미리 다운받아놓고 삭제해도
# 나중에 무료로 다운 가능합니다.
#
# https://play.google.com/store/apps/details?id=com.bornehltd.photoeditorpro
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 어제부터 아트뮤딜 놓치고 무선충전기 찾고 있는데 나쁘지 않아보이네요.
#
# 모즈온은 처음 들어보는 회사인데 네이버 검색에도 딱히 후기가 없긴 합니다. 그래도 중국산 oem은 다 비슷하지 않을까 싶어서 하나 구매해봅니다.
#
# 원래 점심에는 아래 제품을 결제했었었는데 아직 배송이 안되어서 위 제품으로 갈아탑니다. 오늘만 벌써 몇 번이나 결제하고 취소하는지 모르겠네요ㅠ 아까 올라온 제품도 댓글이 별로라 취소하고...
#
# Aura 2x 거치형 무선충전기
#
# http://mobile.ticketmonster.co.kr/deals/1841881234
#
#
#
# 외관이나 성능 역시 유사해보입니다.
#
# 차이는 위 제품은 c타입 아래는 5pin입니다. 둘 다 캐이블 포함입니다.
#
# 아래 제품은 네이버 후기도 많네요. 바이럴도 섞여 있는 거 같으니 적당히 보시면 되겠습니다. 그나마 Aura 제품은 겨울에 손난로 찾아볼 때 몇 번 본 거 같네요.
#
# 같은 회사로 거치형+패드형 둘 다 되는 Aura 3x가 있긴 한데 25,000원 정도로 비싸네요.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 티몬 1212 딜로 동원 다방커피 250ml×12개짜리
# 7,900원에 무료배송 행사 공유합니다.
#
# 맛은 오리지널, 헤이즐넛 2개이고 각 12개 기준으로
# 7,900원이네요. 최저가 검색해보니 6개가 조금 더
# 싼걸 감안하면 사두고 하나씩 마시면 좋을 것 같네요.
#
# 저는 평소에 오리지널을 즐겨 마시는 편인데 무난한거
# 같습니다. (헤이즐럿은 잘 모르겠습니다.)
#
# 심야딜,모닝딜 등 많은 딜들로 구경하고 구매하는
# 재미는 있는데 경비실에 택배 박스 쌓이는게 민망한 ^^; 구매가능시간은 12시간 정도 남았으니 참고하세요!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 안녕하세요.
#
#
#
#
#
# * GS25 편의점 모바일 상품권 1만원권 (8,900원/무료)
#
#
#
#
#
# 간만에 적립금 사용 가능하여 올려 봅니다.
#
#
# 유효기간은 6개월 입니다.
#
#
#
#
#
# 틀린부분 댓글 주시면 수정하겠습니다.
#
#
# 편안한 밤 보내세요.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 기간만료 Gs포인트 소진용이에요.
# 2000원 쓰면 820원으로 살수있어요.
# 색깔이 예뻐용. 말랑말랑할것같아요.
# 집에 키보드는 없는데 아이가 있으신분은
# 아래 아동 털실내화도 괜찮아보여요.
# (3000원/무배) 예요.
#
# http://m.gsshop.com/prd/prd.gs?prdid=33268593&mseq=401139&gsid=srcheshop-result&kwd=털실내화&ab=df
#
# 저는 집에 아이가 있어서 털실내화 샀어용.
# 젤클리너 사면 아들한테 슬라임용도로 뺏길것같았어요.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 쿠폰/혜택 페이지
# http://www.jungoneshop.com/benefit/couponBook?tracking=gnb_coupon
#
# 5만원 이상 구매시 전체 쿠폰 받아서 30%할인쿠폰 적용: 최대 3만원
# 정원 클래식(연회비 회원을 의미) 쿠폰 10%는 클래식 회원이면 자동
#
# 배송비는 클래식 회원이면 여러번 무료, 이 제품 3만원 넘으면 무료
#
# 그럼 청정원 안주야 불족발이 맞있는가가 문제인데, 곱창, 닭발보다 맛있습니다. 껍데기가 맛있어요. 불족발은 덤인 격
# 저는 불족발 > 곱창 > 주꾸미 순으로 맛있습니다.
#
# 햇반에 비벼 먹으면 좋아요. 3팩짜리 6묶음 총 18개 샀습니다.
#
# 3월 30% 쿠폰이니 일단 쓰고 봅니다. 돈 남겨줄 처자식 없습니다. 골든 햄스터만 있는데 저보다 오래 못살듯 ㅠ
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# None
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 제가 구매하려고 오늘 틈틈히 검색해보다가 여기가 제일 싼듯해서 공유차 글을 올립니다.
#
# 사실 오늘 알리 쿠폰이 풀려서 그걸로 구매를 하려고 했는데요;; 지마켓이 더 저렴하네요;;
#
# 일단 기본가격에 스마일클럽 쿠폰 10% 쿠폰시 23130원 12% 쿠폰시 22700원이 나옵니다.
#
# 스마일클럽 아니신분들께는 죄송합니다;; 어떤 쿠폰이 있는지 확인을 못했습니다;;
#
# 다른 판매자 제품 같은경우 쿠폰할인이 달라서 가격에 저렴함에도 불구하고 여기가 더 쌉니다.
#
# 저기다가 컬쳐캐쉬 9%+오캐이캐쉬백 2%+적립(캐쉬68, 혹은 포인트68) 하면 최저가 2만원 정도 나옵니다!!
#
# 뽐게에도 몇번 올라온 제품이라 따로 이미지는 올리지 않겠습니다.
#
# 그리고 QCY 제품과 비교들 많이 하시던데 저는 음질은 어짜피 개인차가 크고 환경에 따라 달라질수 있다고 생각해서
#
# 따로 어느것이 좋은지는 모르겠습니다. 그냥 저는 가성비하나 보고 구매해 보는거라서요~ 뽑기운이 좋아야할텐데 말이죠;;ㅎㅎ
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 뒤늦게(?) 회사 동료땜에 배그에 빠져가꼬 쓸만한 게이밍 노트북 구매 후 공유합니다
# 참고로 다나와 / 네이버 최저가는 이렇네요 1,169,000 / 1,149,000간단 사양 :
#
# 인텔 / 코어i7-8세대 / 커피레이크 / i7-8750H 2.2GHz(4.1GHz) / 헥사 코어 / 39.62cm(15.6인치) / 1920x1080 / 눈부심방지 / 슬림형 베젤 / 8GB / DDR4 / 1TB / 지포스 GTX1060 / VRAM:6GB / 1Gbps 유선랜 / 802.11 n/ac 무선랜 / 블루투스 5.0 / HDMI 2.0 / 웹캠 / USB 3.0 / USB 2.0 / 숫자 키패드 / 블록 키보드 / 키보드 라이트 / MIL-STD / 48Wh / 운영체제 미포함 / 두께:26mm / 2.2Kg / 용도: 게임용 , 그래픽작업용 / 색상: 블랙일단 위메프 링크 걸면 뽐뿌사장님 배불리는거기 때문에 최저가로 제가 구매했던 방법  알려드립니다.
#
# 최저가 구매방법 (위에 캡쳐 참고)
# 1. 위에 링크로 접속하여 쇼핑하기 클릭 (이베이츠 가입안하신 분은 하시고 하셔야 적립되요)https://www.ebates.com/kr/coupons/we-make-price
# 2. 위메프가 켜질텐데 검색창에 FX505GM 검색
# 3. 일반상품 왼쪽에서 첫번째꺼 선택
# 4. 쿠폰다운받기 누르고 [디지털/가전] 시크릿 쿠폰 127,000원 할인, 신한/삼성/국민 카드 3% 추가할인 쿠폰 받기 (귀찮으면 다 받으세요)
# 5. 모든 쿠폰 적용하고 신한/삼성/국민카드 중 하나로 구매시 1,080,650원 -> 더 싼 방법 찾으시는 능력자분은 공유좀여 취소하고 다시사게
# 6. 최종가 1,080,650 - 이베이츠 1.5% 적립(약 16,209원) = 1,064,440원
# 7. 아 그딴거 모르겠고 상품 링크내놔 하시는 분들 위해 : https://front.wemakeprice.com/product/148800104?source=dealsearch&search_keyword=fx505gm&no=1&_service=3
# 끄읏
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 헤드앤숄더 신상하고 인기샴푸/린스 850ml3개 쿠폰 먹여서 17,180원 나오네요. 사은품으로 타월이랑 샘플2개 주니까 나쁘지 않은 가격같아요
# 샴푸 떨어지신분 참고하셔요~
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 안녕하세요 동네마실용 츄리닝 한벌 입니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상세페이지 중간에 보이는  15% 쿠폰 받는거 받아서 적용하면 36,390원.
#
# 농협,비씨,현대,신한,국민 카드 로 결제하면 7% 할인 받아서 33,850원.
#
# 오케이캐쉬백 경유 2% 적립하면 33,170원.
#
# 스마일캐시 109원 적립되니..33,070원쯤? 에 츄리닝 한번+맨투맨티 1개 입니다.
#
#
#
#
#
#
#
#
#
#
#
# 또 츄리닝 한벌 사면 같이 주는 맨투맨티가 이뻐보입니다. (휠라 맨투맨 색상과 비슷한?)
#
# 실은 저도 츄리닝 바지랑 맨투맨티가 땡겨서 지른겁니다.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
# 게시글 코멘트 (//To-Do)
comments = bbs.getComments()
for comment in comments:
    print(comment)
    print(-" * 50)
# Out:
# 32ud59 쓰는데, 사고싶네요 ㅠㅠ
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 역대가인가요?
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 4k는 1080ti로는 60프레임 방어가 힘들까요??
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 2070정도면 타협하고 쓸만하실껍니다
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 이모니터에 1080물리면 뭉개지나요?
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 1위는 32ul950 입니다. 근데가격이 백만원 넘어가요. 엘지행사할때마다 좀 행사좀 하라고 썼는데 이놈을 하는군요.va패널이라 심히 고민되네요. 엘지 ips는 진짜 괜찮은데..혹시 써보신분 계신가요, 별차이 없으면 이걸로 가고싶네요
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 전 벤큐꺼 32인치 4k hdr지원모델 쓰는데 va생각보다 괜찮어요 전 usb c 입력이 끌려서 밴큐로.. 패널은 아마 같을겁니다
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 쇼핑몰 운영중인 사람인데요 현재 모니터로 색감을 맞추면 모바일에선 좀다르게 보이더라구요 이친구는 괜찮을까요???
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 850f와 비교하면 어떨까요? 용도는 플스입다
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 32GK650 시리즈랑 차이가 많이 나나요??? ^^
#
# 헤르츠 / 해상도 차이가 있군요... 4k ㄷㄷ
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 사세요!화질 끝내줍니다!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 네 최근세달기준으로는 그러네요.
# 뽐게에서 850k는 많이 봤는데 이건 추천하는분이 없어서 세달전은 모르겠네요~
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 2080ti도 최근겜들은 옵션타협해야합니다
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# IPS패널보다 좀 쨍한 느낌이 있습니다.
# 모니터사고 초반에 밝은화면 보시면 적응이 힘들수도 있지만, 금방적응됩니다.두달째 잘쓰는중.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 저도 벤큐와 이거 비교해봤는데, 얼마 가격차이가 안나서 이걸로 샀네요~
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 감사합니다. 사야겠네요
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 동일 패널일껄요
# 이노룩스 패널...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# https://m.blog.naver.com/qqqdlrnsk/221413686734
# 참고해 보세요.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 검색해보니 이노룩스va 패널이군요 아놔..구입하려는 분들 확인하고 사세요
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 쇼핑몰 운영하면서 모니터로 색감 맞추실거면
# 모니터 캘리브레이션을 시켜서 사용하시거나, 색 재현력이 높은걸 사용하셔야 합니다.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 쉽게보면 850F는 PC판  게임용으로 용도가 크고, 이건 플스용도로 더 좋다고 보시면되요.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 해상도 말씀이죠? 당연히 뭉개집니다
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 저는 32ud59 샀다가 실망하고 32ud99로 갈아탔어요 ips 쓰시던분이라면 만족못하실수도있습니다
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
# 뽐뿌게시판 전체 리스트  --> //To-Do : numpy 이용해서 행과 열을 Transpose 하고, 게시판 구조로 merger 하기
ppomppu = bbs.getPpomppuBbs()
ppomppu
# Out:
# [['311608',
#   '311607',
#   '311605',
#   '311604',
#   '311603',
#   '311602',
#   '311601',
#   '311600',
#   '311599',
#   '311598',
#   '311597',
#   '311596',
#   '311595',
#   '311594',
#   '311593',
#   '311592',
#   '311591',
#   '311590',
#   '311588',
#   '311587'],
#  ['기타',
#   '먹을거리',
#   '기타',
#   '먹을거리',
#   '의류/잡화',
#   '먹을거리',
#   '의류/잡화',
#   '기타',
#   '기타',
#   '컴퓨터',
#   '기타',
#   '기타',
#   '디지털',
#   '디지털',
#   '의류/잡화',
#   '의류/잡화',
#   '먹을거리',
#   '기타',
#   '컴퓨터',
#   '화장품'],
#  ['당신의지갑에구멍을',
#   '비타민원츄',
#   '루어루어',
#   'best1985',
#   '사기치지말자',
#   '르르랑',
#   '루이렉스',
#   'γ^^γ가든~♡',
#   '하진제',
#   'braydlgt',
#   '웰컴이다',
#   '샤프1004',
#   '초로롱초롱',
#   'ARIUM',
#   '감지기',
#   '백묘s',
#   'Rhaon',
#   '음랴리',
#   '흑곰하나',
#   '수진ㅇㅣ'],
#  ['[하이마트몰] 해밀턴비치 이지스팀백 의류관리기 S07 (82,650원/무료) 최대 78,300원',
#   '[티몬] 동원 다방커피 250ml×12개 오리지널/헤이즐넛 (7,900원/무료배송)',
#   '[티몬] GS25 편의점 모바일 상품권 1만원권 (8,900원/무료) 적립금 사용 가능',
#   '[Gs shop] 젤클리너 (2820원/ 무료)',
#   '[정원e샵] 청정원 안주야 불족발&껍데기180gx3개 / 정원 클래식가입자만 가성비 있음 (16,900/2,500)',
#   '[티몬] 트렉스타 남녀 트레킹화 4종 (10,500원/무료)',
#   '[G마켓] IP010-X Pro 알리캡슐 블루투스 무선 이어폰 (25,700/무배)',
#   '[위메프] ASUS 게이밍 노트북 TUF FX505GM-BQ234 (1,199,000원 -> 모든 할인/적립 적용 시 1,064,500원/무료)',
#   '[11번가] 헤드앤숄더 신상/베스트 850mlX3+풋볼타월+샘플80mlx2개 (쿠폰가 17,180 / 무료배송)',
#   '[G마켓]험멜 쉐브론 트랙수트 3종(43,590/무료)',
#   '[GSSHOP] [체험상품] 강아지 애견 사료/간식 샘플 모음전(2,500/무료)',
#   '[위메프] 신세계 상품권 10만원권',
#   '[티몬] LG 32UK550  ( 625,000원 / 무배 ) 국민카드 결제시 30,000원 중복할인'],
#  ['http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311608',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311607',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311605',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311603',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311602',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311601',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311600',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311598',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311597',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311592',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311591',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311590',
#   'http://www.ppomppu.co.kr/zboard/view.php?id=ppomppu&page=1&divpage=54&no=311588'],
#  ['http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/8/small_311608.jpg?t=20190314002244',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/7/small_311607.jpg?t=20190313235950',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/5/small_311605.jpg?t=20190314000138',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/4/small_311604.jpg?t=20190313235327',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/3/small_311603.jpg?t=20190313232649',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/2/small_311602.jpg?t=20190313224720',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/1/small_311601.jpg?t=20190313222336',
#   'http://static.ppomppu.co.kr/www/img/noimage/noimage_60x50.jpg',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/9/small_311599.jpg?t=20190313213547',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/8/small_311598.jpg?t=20190313212923',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/7/small_311597.jpg?t=20190313204210',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/6/small_311596.jpg?t=20190313211840',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/5/small_311595.jpg?t=20190313202512',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/4/small_311594.jpg?t=20190313202330',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/3/small_311593.jpg?t=20190313194948',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/2/small_311592.jpg?t=20190313191252',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/1/small_311591.jpg?t=20190313190438',
#   'http://static.ppomppu.co.kr/www/img/noimage/noimage_60x50.jpg',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/8/small_311588.jpg?t=20190313180859',
#   'http://cdn.ppomppu.co.kr/zboard/data/_thumb/ppomppu/7/small_311587.jpg?t=20190313181334'],
#  ['images/ppompu/2019-03-14_00-31/small_311608.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311607.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311605.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311604.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311603.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311602.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311601.jpg',
#   'images/ppompu/2019-03-14_00-31/noimage_60x50.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311599.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311598.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311597.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311596.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311595.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311594.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311593.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311592.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311591.jpg',
#   'images/ppompu/2019-03-14_00-31/noimage_60x50.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311588.jpg',
#   'images/ppompu/2019-03-14_00-31/small_311587.jpg'],
#  [0, 6, 6, 15, 41, 24, 55, 15, 73, 78, 14, 64, 30],
#  ['13.10.24 13:24:54',
#   '19.03.14 00:24:52',
#   '19.03.14 00:03:42',
#   '19.03.14 00:01:04',
#   '19.03.13 23:56:57',
#   '19.03.13 23:29:48',
#   '19.03.13 22:44:17',
#   '19.03.13 22:27:28',
#   '19.03.13 22:01:19',
#   '19.03.13 21:36:06',
#   '19.03.13 21:33:15',
#   '19.03.13 20:46:03',
#   '19.03.13 20:42:41',
#   '19.03.13 20:29:05',
#   '19.03.13 20:21:21',
#   '19.03.13 19:53:40',
#   '19.03.13 19:16:44',
#   '19.03.13 19:06:15',
#   '19.03.13 18:54:57',
#   '19.03.13 18:12:51',
#   '19.03.13 18:10:10'],
#  [0, 3, 14, 0, 8, 6, 4, 12, 4, 0, 23, 10, 5, 5, 1, 35, 5, 2, 9, 0],
#  [401,
#   1059,
#   1500,
#   814,
#   4003,
#   4000,
#   7034,
#   12221,
#   3070,
#   4005,
#   8731,
#   10148,
#   12014,
#   18054,
#   8846,
#   23728,
#   2813,
#   8371,
#   11992,
#   2064],
#  [['스타일러를 흉내낸.. 가성비로 쓰는 그런 제품인거 같네요.\n\xa0\n지난번엔 빠른 품절이였는데 이번에는 여유있게 구매 가능한거 같네요.\n\xa0\n6개 남았습니다.\n\xa0\n정상가 169,000\n쿠폰할인 82,000\nNH농협, KB국민 카드 청구할인 4,350\nAPP&LPay 결제 포인트 적립 신청 4,350\n---------------------------------------------------\n최종 78,300원'],
#   ['티몬 1212 딜로 동원 다방커피 250ml×12개짜리\n7,900원에 무료배송 행사 공유합니다.\n\xa0\n맛은 오리지널, 헤이즐넛 2개이고 각 12개 기준으로\n7,900원이네요. 최저가 검색해보니 6개가 조금 더\n싼걸 감안하면 사두고 하나씩 마시면 좋을 것 같네요.\n\xa0\n저는 평소에 오리지널을 즐겨 마시는 편인데 무난한거\n같습니다. (헤이즐럿은 잘 모르겠습니다.)\n\xa0\n심야딜,모닝딜 등 많은 딜들로 구경하고 구매하는\n재미는 있는데 경비실에 택배 박스 쌓이는게 민망한 ^^; 구매가능시간은 12시간 정도 남았으니 참고하세요!'],
#   ['안녕하세요.\n\n\n\xa0\n\n\n* GS25 편의점 모바일 상품권 1만원권 (8,900원/무료)\xa0\n\n\n\xa0\n\n\n간만에 적립금 사용 가능하여 올려 봅니다.\n\n\n유효기간은 6개월 입니다.\n\n\n\xa0\n\n\n틀린부분 댓글 주시면 수정하겠습니다.\n\n\n편안한 밤 보내세요.'],
#   ['기간만료 Gs포인트 소진용이에요.\xa0\n2000원 쓰면 820원으로 살수있어요.\n색깔이 예뻐용. 말랑말랑할것같아요.\n집에 키보드는 없는데 아이가 있으신분은\n아래 아동 털실내화도 괜찮아보여요.\n(3000원/무배) 예요.\n\xa0\nhttp://m.gsshop.com/prd/prd.gs?prdid=33268593&mseq=401139&gsid=srcheshop-result&kwd=털실내화&ab=df\n\xa0\n저는 집에 아이가 있어서 털실내화 샀어용.\n젤클리너 사면 아들한테 슬라임용도로 뺏길것같았어요.'],
#   ['쿠폰/혜택 페이지\nhttp://www.jungoneshop.com/benefit/couponBook?tracking=gnb_coupon\n\xa0\n5만원 이상 구매시 전체 쿠폰 받아서 30%할인쿠폰 적용: 최대 3만원\n정원 클래식(연회비 회원을 의미) 쿠폰 10%는 클래식 회원이면 자동\n\xa0\n배송비는 클래식 회원이면 여러번 무료, 이 제품 3만원 넘으면 무료\n\xa0\n그럼 청정원 안주야 불족발이 맞있는가가 문제인데, 곱창, 닭발보다 맛있습니다. 껍데기가 맛있어요. 불족발은 덤인 격\n저는 불족발 > 곱창 > 주꾸미 순으로 맛있습니다.\n\xa0\n햇반에 비벼 먹으면 좋아요. 3팩짜리 6묶음 총 18개 샀습니다.\n\xa0\n3월 30% 쿠폰이니 일단 쓰고 봅니다. 돈 남겨줄 처자식 없습니다. 골든 햄스터만 있는데 저보다 오래 못살듯 ㅠ'],
#   None,
#   ['제가 구매하려고 오늘 틈틈히 검색해보다가 여기가 제일 싼듯해서 공유차 글을 올립니다.\n\xa0\n사실 오늘 알리 쿠폰이 풀려서 그걸로 구매를 하려고 했는데요;; 지마켓이 더 저렴하네요;;\n\xa0\n일단 기본가격에 스마일클럽 쿠폰 10% 쿠폰시 23130원 12% 쿠폰시 22700원이 나옵니다.\n\xa0\n스마일클럽 아니신분들께는 죄송합니다;; 어떤 쿠폰이 있는지 확인을 못했습니다;;\n\xa0\n다른 판매자 제품 같은경우 쿠폰할인이 달라서 가격에 저렴함에도 불구하고 여기가 더 쌉니다.\n\xa0\n저기다가 컬쳐캐쉬 9%+오캐이캐쉬백 2%+적립(캐쉬68, 혹은 포인트68) 하면 최저가 2만원 정도 나옵니다!!\n\xa0\n뽐게에도 몇번 올라온 제품이라 따로 이미지는 올리지 않겠습니다.\n\xa0\n그리고 QCY 제품과 비교들 많이 하시던데 저는 음질은 어짜피 개인차가 크고 환경에 따라 달라질수 있다고 생각해서\n\xa0\n따로 어느것이 좋은지는 모르겠습니다. 그냥 저는 가성비하나 보고 구매해 보는거라서요~ 뽑기운이 좋아야할텐데 말이죠;;ㅎㅎ'],
#   ['뒤늦게(?) 회사 동료땜에 배그에 빠져가꼬 쓸만한 게이밍 노트북 구매 후 공유합니다\n참고로 다나와 / 네이버 최저가는 이렇네요 1,169,000 / 1,149,000간단 사양 :\xa0\n\n인텔\xa0/\xa0코어i7-8세대\xa0/\xa0커피레이크\xa0/\xa0i7-8750H 2.2GHz(4.1GHz)\xa0/\xa0헥사 코어\xa0/\xa039.62cm(15.6인치)\xa0/\xa01920x1080\xa0/\xa0눈부심방지\xa0/\xa0슬림형 베젤\xa0/\xa08GB\xa0/\xa0DDR4\xa0/\xa01TB\xa0/\xa0지포스 GTX1060\xa0/\xa0VRAM:6GB\xa0/\xa01Gbps 유선랜\xa0/\xa0802.11 n/ac 무선랜\xa0/\xa0블루투스 5.0\xa0/\xa0HDMI 2.0\xa0/\xa0웹캠\xa0/\xa0USB 3.0\xa0/\xa0USB 2.0\xa0/\xa0숫자 키패드\xa0/\xa0블록 키보드\xa0/\xa0키보드 라이트\xa0/\xa0MIL-STD\xa0/\xa048Wh\xa0/\xa0운영체제 미포함\xa0/\xa0두께:26mm\xa0/\xa02.2Kg\xa0/\xa0용도:\xa0게임용\xa0,\xa0그래픽작업용\xa0/ 색상: 블랙일단 위메프 링크 걸면 뽐뿌사장님 배불리는거기 때문에 최저가로 제가 구매했던 방법\xa0 알려드립니다.\n\n최저가 구매방법 (위에 캡쳐 참고)\n1. 위에 링크로 접속하여 쇼핑하기 클릭 (이베이츠 가입안하신 분은 하시고 하셔야 적립되요)https://www.ebates.com/kr/coupons/we-make-price\xa0\n2. 위메프가 켜질텐데 검색창에 FX505GM 검색\n3. 일반상품 왼쪽에서 첫번째꺼 선택\n4. 쿠폰다운받기 누르고 [디지털/가전] 시크릿 쿠폰 127,000원 할인, 신한/삼성/국민 카드 3% 추가할인 쿠폰 받기 (귀찮으면 다 받으세요)\n5. 모든 쿠폰 적용하고 신한/삼성/국민카드 중 하나로 구매시 1,080,650원 -> 더 싼 방법 찾으시는 능력자분은 공유좀여 취소하고 다시사게\n6. 최종가 1,080,650 - 이베이츠 1.5% 적립(약 16,209원) = 1,064,440원\xa0\n7. 아 그딴거 모르겠고 상품 링크내놔 하시는 분들 위해 : https://front.wemakeprice.com/product/148800104?source=dealsearch&search_keyword=fx505gm&no=1&_service=3\n끄읏'],
#   ['헤드앤숄더 신상하고 인기샴푸/린스 850ml3개 쿠폰 먹여서 17,180원 나오네요. 사은품으로 타월이랑 샘플2개 주니까 나쁘지 않은 가격같아요\n샴푸 떨어지신분 참고하셔요~'],
#   ['안녕하세요 동네마실용 츄리닝 한벌 입니다.\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n상세페이지 중간에 보이는\xa0 15% 쿠폰 받는거 받아서 적용하면 36,390원.\n\xa0\n농협,비씨,현대,신한,국민 카드 로 결제하면 7% 할인 받아서 33,850원.\n\xa0\n오케이캐쉬백 경유 2% 적립하면 33,170원.\n\xa0\n스마일캐시 109원 적립되니..33,070원쯤? 에 츄리닝 한번+맨투맨티 1개 입니다.\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n또 츄리닝 한벌 사면 같이 주는 맨투맨티가 이뻐보입니다. (휠라 맨투맨 색상과 비슷한?)\n\xa0\n실은 저도 츄리닝 바지랑 맨투맨티가 땡겨서 지른겁니다.'],
#   ['gsshop 2000원 적립금 내일까지라고 떠서 뭐살까 알아보다가 강아지 사료/간식샘플 판매글 있어서 구매했어요ㅎㅎ\n\xa0\n사료나 간식은 집에 좀 있고해서 껌 선택하고, 적립금2000원 써서 500원 결제했어요ㅎㅎ\n\xa0\n혹시나 적립금 어디다 쓰지 하시는분들 있을까봐 공유해요ㅎㅎ\n업체가 문제있거나 양식에 문제있으면 삭제하거나 수정할게요..!'],
#   ['위메프 신세계 상품권 10만원권 50만원권\n쿠폰 떴습니다.\n네이버 위메프 경유로 들어가신후.\n2.5%쿠폰 받으심 됩니다.\n그럼 수고!!'],
#   ['LG 32인치 4K모니터입니다.\n4K HDR 을 지원하는 모니터중에서는 가성비 최고의 모델입니다.\n1위모델이 가격대와 모델명이 생각이 안나는데...(모바일이 이해를...)\n1위모델이 IPS패널을 사용하지만 가격은 두배이상입니다.(이 모델은 VA패널입니다.)\n얼추 두달전에 플스대란후 고민끝에 질렀는데,\xa0 항상 가격대가 60초반에서 안 내려와서 포기하고 컬쳐질로 이가격대에 구입했습니다.\n국민카드가 있는분에 한하여 50대 후반 턱걸이니, 추천합니다.']],
#  ['32ud59 쓰는데, 사고싶네요 ㅠㅠ',
#   '역대가인가요?',
#   '4k는 1080ti로는 60프레임 방어가 힘들까요??',
#   '2070정도면 타협하고 쓸만하실껍니다',
#   '이모니터에 1080물리면 뭉개지나요?',
#   '1위는 32ul950 입니다. 근데가격이 백만원 넘어가요. 엘지행사할때마다 좀 행사좀 하라고 썼는데 이놈을 하는군요.va패널이라 심히 고민되네요. 엘지 ips는 진짜 괜찮은데..혹시 써보신분 계신가요, 별차이 없으면 이걸로 가고싶네요',
#   '전 벤큐꺼 32인치 4k hdr지원모델 쓰는데 va생각보다 괜찮어요 전 usb c 입력이 끌려서 밴큐로.. 패널은 아마 같을겁니다',
#   '쇼핑몰 운영중인 사람인데요 현재 모니터로 색감을 맞추면 모바일에선 좀다르게 보이더라구요 이친구는 괜찮을까요???',
#   '850f와 비교하면 어떨까요? 용도는 플스입다',
#   '32GK650 시리즈랑 차이가 많이 나나요??? ^^\n\n헤르츠 / 해상도 차이가 있군요... 4k ㄷㄷ',
#   '사세요!화질 끝내줍니다!',
#   '네 최근세달기준으로는 그러네요.\n뽐게에서 850k는 많이 봤는데 이건 추천하는분이 없어서 세달전은 모르겠네요~',
#   '2080ti도 최근겜들은 옵션타협해야합니다',
#   'IPS패널보다 좀 쨍한 느낌이 있습니다.\n모니터사고 초반에 밝은화면 보시면 적응이 힘들수도 있지만, 금방적응됩니다.두달째 잘쓰는중.',
#   '저도 벤큐와 이거 비교해봤는데, 얼마 가격차이가 안나서 이걸로 샀네요~',
#   '감사합니다. 사야겠네요',
#   '동일 패널일껄요\n이노룩스 패널...',
#   'https://m.blog.naver.com/qqqdlrnsk/221413686734\n참고해 보세요.',
#   '검색해보니 이노룩스va 패널이군요 아놔..구입하려는 분들 확인하고 사세요',
#   '쇼핑몰 운영하면서 모니터로 색감 맞추실거면\n모니터 캘리브레이션을 시켜서 사용하시거나, 색 재현력이 높은걸 사용하셔야 합니다.',
#   '쉽게보면 850F는 PC판  게임용으로 용도가 크고, 이건 플스용도로 더 좋다고 보시면되요.',
#   '해상도 말씀이죠? 당연히 뭉개집니다',
#   '저는 32ud59 샀다가 실망하고 32ud99로 갈아탔어요 ips 쓰시던분이라면 만족못하실수도있습니다']]
